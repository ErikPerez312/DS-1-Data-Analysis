# %% [markdown]
# ![Screen%20Shot%202018-01-25%20at%2010.21.37%20AM.png](attachment:Screen%20Shot%202018-01-25%20at%2010.21.37%20AM.png)

# %% [markdown]
# **SOLUTION**: Select * FROM CITY WHERE COUNTRYCODE = 'USA' AND POPULATION > 100000

# %% [markdown]
# ![Screen%20Shot%202018-01-25%20at%2010.28.56%20AM.png](attachment:Screen%20Shot%202018-01-25%20at%2010.28.56%20AM.png)

# %% [markdown]
# **SOLUTION**: SELECT name FROM city WHERE population > 120000 and countrycode = 'USA'

# %% [markdown]
# ![Screen%20Shot%202018-01-25%20at%2010.29.40%20AM%202.png](attachment:Screen%20Shot%202018-01-25%20at%2010.29.40%20AM%202.png)

# %% [markdown]
# ![Screen%20Shot%202018-01-25%20at%2010.29.40%20AM.png](attachment:Screen%20Shot%202018-01-25%20at%2010.29.40%20AM.png)

# %% [markdown]
# **SOLUTION**: SELECT * FROM city

# %% [markdown]
# ![Screen%20Shot%202018-01-25%20at%2010.46.54%20AM.png](attachment:Screen%20Shot%202018-01-25%20at%2010.46.54%20AM.png)

# %% [markdown]
# **SOLUTION**: SELECT DISTINCT city FROM station WHERE id % 2 = 0
